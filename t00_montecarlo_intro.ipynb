# %% [markdown]
# # Monte Carlo - Probando algunos conceptos
#
# En este cuaderno solo probamos algunos conceptos generales de trabajo.

# %%
import math
import matplotlib as mpl
import matplotlib.pyplot as plt

x = list(range(100))
y = []
for x0 in x:
    y.append(math.sin(4*3.14*x0/100))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\carlos\Documents\GitHub\fing-montercarlo-2022\t00_montecarlo_intro.ipynb Cell 2' in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/carlos/Documents/GitHub/fing-montercarlo-2022/t00_montecarlo_intro.ipynb#ch0000001?line=0'>1</a> import math
# ----> <a href='vscode-notebook-cell:/c%3A/Users/carlos/Documents/GitHub/fing-montercarlo-2022/t00_montecarlo_intro.ipynb#ch0000001?line=1'>2</a> import matplotlib as mpl
#       <a href='vscode-notebook-cell:/c%3A/Users/carlos/Documents/GitHub/fing-montercarlo-2022/t00_montecarlo_intro.ipynb#ch0000001?line=2'>3</a> import matplotlib.pyplot as plt
#       <a href='vscode-notebook-cell:/c%3A/Users/carlos/Documents/GitHub/fing-montercarlo-2022/t00_montecarlo_intro.ipynb#ch0000001?line=4'>5</a> x = list(range(100))
#
# ModuleNotFoundError: No module named 'matplotlib'

# %% [markdown]
# ## Grafica de la funcion seno

# %%
plt.plot(x,y)
