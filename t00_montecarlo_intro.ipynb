# %% [markdown]
# # Monte Carlo - Probando algunos conceptos
#
# En este cuaderno solo probamos algunos conceptos generales de trabajo.

# %%
import math
import matplotlib as mpl
import matplotlib.pyplot as plt

x = list(range(100))
y = []
for x0 in x:
    y.append(math.sin(3*3.14*x0/100))

# %% [markdown]
# ## Grafica de la funcion seno

# %%
plt.plot(x,y)
